# %% [markdown]
# <a href="https://colab.research.google.com/github/NafisFuadTanvir/Machine-learning-works/blob/main/201002437_ans_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("/content/data_banknote_authentication.csv")

# %%
dataset
# Out:
#       Variance of the intensity  Skewness of the intensity  \
# 0                       3.62160                    8.66610
# 1                       4.54590                    8.16740
# 2                       3.86600                   -2.63830
# 3                       3.45660                    9.52280
# 4                       0.32924                   -4.45520
# ...                         ...                        ...
# 1367                    0.40614                    1.34920
# 1368                   -1.38870                   -4.87730
# 1369                   -3.75030                  -13.45860
# 1370                   -3.56370                   -8.38270
# 1371                   -2.54190                   -0.65804
#
#       Kurtosis of the intensity  Entropy  Target
# 0                       -2.8073 -0.44699       0
# 1                       -2.4586 -1.46210       0
# 2                        1.9242  0.10645       0
# 3                       -4.0112 -3.59440       0
# ...

# %%
newdataset = list(dataset)
newdataset.remove('Skewness of the intensity')
dataset = dataset[newdataset]

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=30)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
y_pred = log.predict(X_test)

# %%
from sklearn import metrics
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy = ",accuracy)
# Out:
# Accuracy =  0.8859223300970874

# %%
df = pd.DataFrame({"predicted": y_pred,"actual": y_test})
df.head(20)
# Out:
#       predicted  actual
# 1090          1       1
# 644           0       0
# 1315          1       1
# 446           0       0
# 128           0       0
# 471           0       0
# 1157          1       1
# 1250          1       1
# 986           1       1
# 215           0       0
# 957           1       1
# 971           1       1
# 1272          1       1
# 494           0       0
# 1059          1       1
# 249           0       0
# 1211          1       1
# 436           1       0
# 1037          1       1
# 804           1       1
