# %% [markdown]
# <a href="https://colab.research.google.com/github/NafisFuadTanvir/Machine-learning-works/blob/main/tryingLeniarRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset= pd.read_csv("/content/student_scores - student_scores.csv")
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.plot(x="Hours",y="Scores",style="o")
plt.title("Hours vs percentage")
plt.xlabel("Hours Studid")
plt.ylabel("percentage score")
plt.show()

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 2.018160041434662
# [9.91065648]

# %%
y_pred=regressor.predict(X_test)
df=pd.DataFrame({"Actual":Y_test,"predictad":y_pred})
df.head()
# Out:
#    Actual  predictad
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
from sklearn import metrics
print("Mean square error:",metrics.mean_squared_error(Y_test,y_pred))
# Out:
# Mean square error: 21.598769307217456
